# %% [markdown]
# # url: https://aiacademy.jp/media/?p=2332

# %% [markdown]
# ABC分析とは、パレートの法則に基づいた分析手法です。 パレート分析などとも呼ばれます。
#
# パレート分析は、売上などの指標の中から重視する評価軸を決め、商品を累積構成比の多い順にA、B、Cの３グループに分類します。
# PythonでABC分析するには色々な方法がありますが、簡単な方法として「abc-analysis」ライブラリを用いる方法です。
#
# 以下のプログラムはABC分析のサンプルプログラムです。
# https://pypi.org/project/abc-analysis/

# %% [markdown]
# ABC分析とは、パレートの法則に基づいた分析手法です。 パレート分析などとも呼ばれます。
#
# パレート分析は、売上などの指標の中から重視する評価軸を決め、商品を累積構成比の多い順にA、B、Cの３グループに分類します。
# PythonでABC分析するには色々な方法がありますが、簡単な方法として「abc-analysis」ライブラリを用いる方法です。
#
# 以下のプログラムはABC分析のサンプルプログラムです。
# https://pypi.org/project/abc-analysis/

# %%
# !pip install abc-analysis

# %%
# https://pypi.org/project/abc-analysis/

from abc_analysis import abc_analysis, abc_plot

# 数値ベクトルに対してABC分析を行う（可視化はしない）
dct_Analysis = abc_analysis([1, 83, 75, 17, 12, 3, 5, 6, 2, 3, 22])

# ABC分析の可視化
dct_Analysis = abc_analysis([1, 83, 75, 17, 12, 3, 5, 6, 2, 3, 22], True)

# abc_plot(dct_Analysis)
